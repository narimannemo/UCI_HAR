# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, Conv1D, Flatten
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
train_data=pd.read_csv('../../Datasets/UCI_HAR/train.csv')
test_data=pd.read_csv('../../Datasets/UCI_HAR/test.csv')

# %%
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
test_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
X=train_data.iloc[:,:-2]
y=train_data.iloc[:,-1]

X_test=test_data.iloc[:,:-2]
y_test=test_data.iloc[:,-1]

# %%
X_test.shape
# Out:
# (2947, 561)

# %%
X = X.values.reshape(7352,561)
X_test=X_test.values.reshape(2947,561)

# %%
labelencoder_y_1 = LabelEncoder()
labelencoder_y_test_1 = LabelEncoder()

y = labelencoder_y_1.fit_transform(y)
y_test = labelencoder_y_test_1.fit_transform(y_test)


y_binary = to_categorical(y)
y_binary_test = to_categorical(y_test)

X = X.reshape(X.shape[0], 561, 1)
X_test = X_test.reshape(X_test.shape[0], 561, 1)

# %%
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(561,1)))
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(6, activation='softmax'))
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X,y_binary,epochs=23)
# Out:
# Epoch 1/23
# 7352/7352 [==============================] - 2s 219us/step - loss: 1.0669 - acc: 0.6257
# Epoch 2/23
# 7352/7352 [==============================] - 1s 103us/step - loss: 0.4666 - acc: 0.8373
# Epoch 3/23
# 7352/7352 [==============================] - 1s 102us/step - loss: 0.2874 - acc: 0.8979
# Epoch 4/23
# 7352/7352 [==============================] - 1s 102us/step - loss: 0.2229 - acc: 0.9184
# Epoch 5/23
# 7352/7352 [==============================] - 1s 104us/step - loss: 0.1761 - acc: 0.9358
# Epoch 6/23
# 7352/7352 [==============================] - 1s 103us/step - loss: 0.1488 - acc: 0.9483
# Epoch 7/23
# 7352/7352 [==============================] - 1s 102us/step - loss: 0.1255 - acc: 0.9591
# Epoch 8/23
# 7352/7352 [==============================] - 1s 101us/step - loss: 0.1105 - acc: 0.9618
# Epoch 9/23
# 7352/7352 [==============================] - 1s 102us/step - loss: 0.1045 - acc: 0.9625
# Epoch 10/23
# ...

# %%
y_prediction = model.predict_classes(X_test)
print ("\n\naccuracy", np.sum(y_prediction == y_test) / float(len(y_test)))
# Out:
# accuracy 0.9586019681031558
